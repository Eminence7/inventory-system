# %%
import pandas as pd
import serial
import time
from datetime import datetime

BAUD_RATE = 9600
RFID_BYTES = 12
START_CHAR = '\x02'
ser = serial.Serial('COM2', BAUD_RATE)
df_main=pd.read_excel(r"C:\Users\jorda\AppData\Roaming\Autodesk\Autodesk Fusion 360\API\Scripts\URDF_Exporter\inventory Main database.xlsx")

dt = datetime.now()
rfid = ser.read(RFID_BYTES)
Box= input()
RFID = rfid
Location= input()
User= input()
#while True:
# Wait until a tag is read
        
print(rfid);
dfadd = pd.DataFrame({"Box": [Box],
        "RFID": [rfid],
        "Location": [Location],
        "User": [User], "Time in":[dt], "Availability": ["Available"]})

frame= [dfadd,df_main]
df_main= pd.concat(frame)
dfadd
#input user name, Locaiton, roup Box/Class
#Manipulate Time in, Time Out, Availability

#we want to make a pandas frame and join it with the main frame.

# %%
df_main.to_excel("inventory Main database.xlsx")

# %%
BAUD_RATE = 9600
RFID_BYTES = 12
START_CHAR = '\x02'
ser = serial.Serial('COM2', BAUD_RATE)
df_main=pd.read_excel(r"C:\Users\jorda\AppData\Roaming\Autodesk\Autodesk Fusion 360\API\Scripts\URDF_Exporter\inventory Main database.xlsx")

#take rfid" direct input data. "where" rfid data is, serialprint "location to arduino"
#take box direct input data.
ret_RFID= input()
ret_Box= input()
dt = datetime.now()

#ret_Location=input()
ret_User=input()

#need to take in more than one peice data.(while loop)
#need to update the last user
#need to update availability
#Search if IDs are in database, if not then give ERROR message, if YES then, send Location
#scan your file, 
#If not in line with requested then ERROR message, If comparable, then validate script retreival and manipulate data.
# send MESSAGE to put back the box
#if request box then all items in box for retreival
ret_RFID= input()
time_delay= time.sleep(10)
ret_Box= input()
ret_User=input()
def retreive_func(ret_RFID,ret_User,ret_Box):
    
    if df_main['RFID'].where(df_main['Subject'] == rfid):
                
        else:
          #   {errormessage}

    if df_main[].where(df_main['Box']=ret_Box)
      #  else {error message}   

        ser.write(df_main['Location'].where(df_main['RFID'or'Box'] == ret_RFID or ret_Box)) 
        #put in delay to wait for ASRS to respond.
        time_delay
        rfid = ser.read(RFID_BYTES) 
            if rfid= ret_RFID:

        else:
            #(Error message) system restart funtion
    
    #if dfdata.where(dfdata['Box'] == ret_Box): 
        
    global ser
    
    if ret_RFID or ret_Box ==df_main[RFID or Box]:  
        df_main.where(df_main['RFID' or 'Box'] == ret_RFID or ret_Box):      
        df_main["Availability"].replace({"unavailable": "available"}, inplace=True)
        df_main[]
        df_main[dt]
